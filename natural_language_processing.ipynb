# %%
import nltk

# %%
from nltk.book import *

# %%
sents()
# Out:
# sent1: Call me Ishmael .
# sent2: The family of Dashwood had long been settled in Sussex .
# sent3: In the beginning God created the heaven and the earth .
# sent4: Fellow - Citizens of the Senate and of the House of Representatives :
# sent5: I have a problem with people PMing me to lol JOIN
# sent6: SCENE 1 : [ wind ] [ clop clop clop ] KING ARTHUR : Whoa there !
# sent7: Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .
# sent8: 25 SEXY MALE , seeks attrac older single lady , for discreet encounters .
# sent9: THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .

# %%
text1.plot(10)

# %%
texts.concordance('the')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-9466bca92d4d> in <module>()
# ----> 1 texts.concordance('the')
#
# AttributeError: 'function' object has no attribute 'concordance'

# %%
text3.similar('the')
# Out:
# his my thy a their her this every that our your thine and of these lo
# god one whose any

# %%
text1.common_contexts(['','gender'])
# Out:
# ('The following word(s) were not found:', 'male gender')

# %%
text1.similar('sex')
# Out:
# by pale heart body gay world while hand others whale fish tongue
# letter word english french poor devil long street

# %%
text1.common_contexts(['tongue','sex'])
# Out:
# the_,

# %%
text1.dispersion_plot(['sex', 'love', 'hate'])

# %%
text4.dispersion_plot(['citizens','democracy', 'freedom', 'duties', 'love' , 'country', 'values'])

# %%
text4.dispersion_plot(['citizens','freedom', 'responsibilities', 'countries', 'values', 'duties', 'people','unity'])

# %%
lexical_diversity(text1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-5edf5239281b> in <module>()
# ----> 1 lexical_diversity(text1)
#
# NameError: name 'lexical_diversity' is not defined

# %%
text3.collocations()
# Out:
# said unto; pray thee; thou shalt; thou hast; thy seed; years old;
# spake unto; thou art; LORD God; every living; God hath; begat sons;
# seven years; shalt thou; little ones; living creature; creeping thing;
# savoury meat; thirty years; every beast

# %%
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %%
text9.collocations()
# Out:
# said Syme; asked Syme; Saffron Park; Comrade Gregory; Leicester
# Square; Colonel Ducroix; red hair; old gentleman; could see; Inspector
# Ratcliffe; Anarchist Council; blue card; Scotland Yard; dark room;
# blue eyes; common sense; straw hat; hundred yards; said Gregory; run
# away

# %%
print(set(sent3) < set(sent2))
print(sent3, sent2)
# Out:
# False
# ['In', 'the', 'beginning', 'God', 'created', 'the', 'heaven', 'and', 'the', 'earth', '.'] ['The', 'family', 'of', 'Dashwood', 'had', 'long', 'been', 'settled', 'in', 'Sussex', '.']

# %%
set(sent4)
# Out:
# {'-',
#  ':',
#  'Citizens',
#  'Fellow',
#  'House',
#  'Representatives',
#  'Senate',
#  'and',
#  'of',
#  'the'}

# %%
set(sent3)
# Out:
# {'.', 'God', 'In', 'and', 'beginning', 'created', 'earth', 'heaven', 'the'}

# %%
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
sent4
# Out:
# ['Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':']
